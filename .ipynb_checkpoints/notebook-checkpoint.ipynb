# %%
import os
import shutil
import kagglehub
from pathlib import Path

target_dir = "../fall-video-dataset"

# Check if dataset already exists
if Path(target_dir).exists() and any(Path(target_dir).iterdir()):
    print("Dataset already exists, skipping download.")
else:
    print("Downloading dataset...")
    path = kagglehub.dataset_download("payutch/fall-video-dataset")
    print("Path to dataset files:", path)

    os.makedirs(target_dir, exist_ok=True)

    for item in os.listdir(path):
        s = os.path.join(path, item)
        d = os.path.join(target_dir, item)

        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            shutil.copy2(s, d)

    print("Dataset copied to:", target_dir)
# Out:
# Dataset already exists, skipping download.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %% [markdown]
# Below is the short description as provided in the kaggle page we downloaded the dataset from Kaggle
#
# ```About this directory```
#
# ```-Raw_Video directory contains raw video footage of human fall.```
#
# ```-Keypoints_CSV directory```
#
# ```-For each input video (e.g., video1.mp4 in Fall/Raw_Video/), the script generates a corresponding CSV file (e.g., video1_keypoints.csv in Fall/Keypoints_CSV/).```
#
# ```-Each CSV file contains frame-by-frame data of the 17 extracted keypoints, their 2D coordinates, and confidence scores.```
#
# ```-The CSV file will have columns: "Frame", "Keypoint", "X", "Y", "Confidence".```
#
#
#
#
#
# Referencing the dataset description on the kaggle page, we load the CSV into frame vectors

# %% [markdown]
# Load and Preprocess the CSV's

# %%
import pandas as pd
import numpy as np 
from pathlib import Path

def load_video_keypoints(csv_path):
    df = pd.read_csv(csv_path)
    frames = sorted(df['Frame'].unique())
    keypoints_per_frame = []

    for frame in frames:
        frame_data = df[df['Frame'] == frame].sort_values('Keypoint')
        # Shape: (17, 3) — x, y, confidence
        kp = frame_data[['X', 'Y', 'Confidence']].values
        keypoints_per_frame.append(kp)

    return np.array(keypoints_per_frame)  # (T, 17, 3)

# %% [markdown]
# Build a Sliding Window Dataset, using 30 frame windows

# %%
def create_sequences(keypoints, label, window_size=30, stride=15):
    sequences, labels = [], []
    T = len(keypoints)
    for start in range(0, T - window_size + 1, stride):
        seq = keypoints[start:start + window_size]  # (30, 17, 3)
        sequences.append(seq)
        labels.append(label)
    return sequences, labels

# Build full dataset
def build_dataset(fall_csv_dir, non_fall_csv_dir, window_size=30):
    X, y = [], []
    for path in Path(fall_csv_dir).glob("*.csv"):
        kp = load_video_keypoints(path)
        seqs, labs = create_sequences(kp, label=1, window_size=window_size)
        X.extend(seqs); y.extend(labs)

    for path in Path(non_fall_csv_dir).glob("*.csv"):
        kp = load_video_keypoints(path)
        seqs, labs = create_sequences(kp, label=0, window_size=window_size)
        X.extend(seqs); y.extend(labs)

    return np.array(X), np.array(y)  # (N, 30, 17, 3)

# %% [markdown]
# Normalize the Data and save as a .npz file

# %%
def normalize_keypoints(X):
    # X shape: (N, T, 17, 3)
    xy = X[..., :2]  # (N, T, 17, 2)
    conf = X[..., 2:3]

    min_xy = xy.min(axis=2, keepdims=True)  # per frame min
    max_xy = xy.max(axis=2, keepdims=True)
    range_xy = np.where((max_xy - min_xy) == 0, 1, max_xy - min_xy)

    xy_norm = (xy - min_xy) / range_xy  # → [0, 1]
    return np.concatenate([xy_norm, conf], axis=-1)


# Run and saved once as sa compressed npz file to quicken training
# X, y = build_dataset(r"..\fall-video-dataset\Fall\Keypoints_CSV", r"..\fall-video-dataset\No_Fall\Keypoints_CSV")
# X = normalize_keypoints(X)

# np.savez_compressed("dataset_cache.npz", X=X, y=y)
data = np.load("dataset_cache.npz")
X, y = data['X'], data['y']

# %% [markdown]
# Train/Validate/Split, so we dont have to make our own training dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, stratify=y_train, random_state=42)

print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")
# Out:
# Train: (20057, 30, 17, 3), Val: (3540, 30, 17, 3), Test: (5900, 30, 17, 3)

# %% [markdown]
# Build CNN (Convolutional Neural Networks) + LSTM (Long Short-Term Memory networks) model

# %%
import tensorflow as tf
from keras import layers, models

def build_cnn_lstm(window_size=30, n_keypoints=17, n_features=3):
    inputs = tf.keras.Input(shape=(window_size, n_keypoints, n_features))

    # --- CNN block applied to each frame via TimeDistributed ---
    x = layers.TimeDistributed(layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'))(inputs)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Conv1D(128, kernel_size=3, activation='relu', padding='same'))(x)
    x = layers.TimeDistributed(layers.GlobalAveragePooling1D())(x)  # (batch, T, 128)

    # --- LSTM block for temporal modeling ---
    x = layers.LSTM(128, return_sequences=True, dropout=0.3)(x)
    x = layers.LSTM(64, dropout=0.3)(x)

    # --- Classifier head ---
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model

model = build_cnn_lstm()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 17, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 30, 17, 64)     │           640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 17, 64)     │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 30, 17, 128)    │        24,704 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 30, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 210,817 (823.50 KB)
#  Trainable params: 210,689 (823.00 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# Compile and Train the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor='val_auc', mode='max'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5),
    tf.keras.callbacks.ModelCheckpoint("best_fall_detection_model.keras", save_best_only=True, monitor='val_auc', mode='max')
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 35s 46ms/step - accuracy: 0.7016 - auc: 0.7030 - loss: 0.5867 - val_accuracy: 0.7822 - val_auc: 0.7887 - val_loss: 0.4966 - learning_rate: 0.0010
# Epoch 2/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.7925 - auc: 0.8139 - loss: 0.4798 - val_accuracy: 0.8184 - val_auc: 0.8567 - val_loss: 0.4313 - learning_rate: 0.0010
# Epoch 3/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8170 - auc: 0.8473 - loss: 0.4394 - val_accuracy: 0.8280 - val_auc: 0.8668 - val_loss: 0.4130 - learning_rate: 0.0010
# Epoch 4/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8303 - auc: 0.8667 - loss: 0.4139 - val_accuracy: 0.8373 - val_auc: 0.8811 - val_loss: 0.3943 - learning_rate: 0.0010
# Epoch 5/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.8373 - auc: 0.8814 - loss: 0.3939 - val_accuracy: 0.8511 - val_auc: 0.8973 - val_loss: 0.3694 - learning_rate: 0.0010
# Epoch 6/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8458 - auc: 0.8918 - loss: 0.3783 - val_accuracy: 0.8548 - val_auc: 0.9069 - val_loss: 0.3534 - learning_rate: 0.0010
# Epoch 7/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8534 - auc: 0.9016 - loss: 0.3607 - val_accuracy: 0.8602 - val_auc: 0.9105 - val_loss: 0.3511 - learning_rate: 0.0010
# Epoch 8/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8568 - auc: 0.9039 - loss: 0.3571 - val_accuracy: 0.8630 - val_auc: 0.9100 - val_loss: 0.3451 - learning_rate: 0.0010
# Epoch 9/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8671 - auc: 0.9154 - loss: 0.3371 - val_accuracy: 0.8686 - val_auc: 0.9216 - val_loss: 0.3262 - learning_rate: 0.0010
# Epoch 10/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 28s 44ms/step - accuracy: 0.8644 - auc: 0.9131 - loss: 0.3413 - val_accuracy: 0.8692 - val_auc: 0.9235 - val_loss: 0.3197 - learning_rate: 0.0010
# Epoch 11/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8754 - auc: 0.9238 - loss: 0.3195 - val_accuracy: 0.8706 - val_auc: 0.9285 - val_loss: 0.3100 - learning_rate: 0.0010
# Epoch 12/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8780 - auc: 0.9259 - loss: 0.3151 - val_accuracy: 0.8816 - val_auc: 0.9327 - val_loss: 0.3015 - learning_rate: 0.0010
# Epoch 13/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8819 - auc: 0.9308 - loss: 0.3025 - val_accuracy: 0.8754 - val_auc: 0.9350 - val_loss: 0.3103 - learning_rate: 0.0010
# Epoch 14/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8864 - auc: 0.9333 - loss: 0.2970 - val_accuracy: 0.8771 - val_auc: 0.9331 - val_loss: 0.3038 - learning_rate: 0.0010
# Epoch 15/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8892 - auc: 0.9378 - loss: 0.2884 - val_accuracy: 0.8879 - val_auc: 0.9387 - val_loss: 0.2910 - learning_rate: 0.0010
# Epoch 16/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8904 - auc: 0.9400 - loss: 0.2834 - val_accuracy: 0.8881 - val_auc: 0.9389 - val_loss: 0.2868 - learning_rate: 0.0010
# Epoch 17/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8951 - auc: 0.9428 - loss: 0.2758 - val_accuracy: 0.8853 - val_auc: 0.9414 - val_loss: 0.2959 - learning_rate: 0.0010
# Epoch 18/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8974 - auc: 0.9459 - loss: 0.2670 - val_accuracy: 0.8918 - val_auc: 0.9440 - val_loss: 0.2880 - learning_rate: 0.0010
# Epoch 19/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.8997 - auc: 0.9484 - loss: 0.2624 - val_accuracy: 0.8966 - val_auc: 0.9464 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 20/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9022 - auc: 0.9512 - loss: 0.2553 - val_accuracy: 0.8955 - val_auc: 0.9509 - val_loss: 0.2780 - learning_rate: 0.0010
# Epoch 21/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9033 - auc: 0.9520 - loss: 0.2528 - val_accuracy: 0.8969 - val_auc: 0.9511 - val_loss: 0.2627 - learning_rate: 0.0010
# Epoch 22/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9047 - auc: 0.9521 - loss: 0.2523 - val_accuracy: 0.8949 - val_auc: 0.9490 - val_loss: 0.2706 - learning_rate: 0.0010
# Epoch 23/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9092 - auc: 0.9551 - loss: 0.2429 - val_accuracy: 0.8997 - val_auc: 0.9526 - val_loss: 0.2637 - learning_rate: 0.0010
# Epoch 24/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9125 - auc: 0.9557 - loss: 0.2392 - val_accuracy: 0.8975 - val_auc: 0.9547 - val_loss: 0.2566 - learning_rate: 0.0010
# Epoch 25/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9095 - auc: 0.9568 - loss: 0.2396 - val_accuracy: 0.9088 - val_auc: 0.9554 - val_loss: 0.2494 - learning_rate: 0.0010
# Epoch 26/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9147 - auc: 0.9601 - loss: 0.2272 - val_accuracy: 0.9079 - val_auc: 0.9554 - val_loss: 0.2572 - learning_rate: 0.0010
# Epoch 27/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9149 - auc: 0.9593 - loss: 0.2305 - val_accuracy: 0.9082 - val_auc: 0.9576 - val_loss: 0.2414 - learning_rate: 0.0010
# Epoch 28/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9143 - auc: 0.9613 - loss: 0.2262 - val_accuracy: 0.9059 - val_auc: 0.9515 - val_loss: 0.2610 - learning_rate: 0.0010
# Epoch 29/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9189 - auc: 0.9625 - loss: 0.2213 - val_accuracy: 0.9023 - val_auc: 0.9561 - val_loss: 0.2653 - learning_rate: 0.0010
# Epoch 30/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9208 - auc: 0.9636 - loss: 0.2157 - val_accuracy: 0.9079 - val_auc: 0.9564 - val_loss: 0.2465 - learning_rate: 0.0010
# Epoch 31/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9204 - auc: 0.9640 - loss: 0.2142 - val_accuracy: 0.9082 - val_auc: 0.9583 - val_loss: 0.2546 - learning_rate: 0.0010
# Epoch 32/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9215 - auc: 0.9671 - loss: 0.2078 - val_accuracy: 0.9107 - val_auc: 0.9632 - val_loss: 0.2325 - learning_rate: 0.0010
# Epoch 33/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9256 - auc: 0.9692 - loss: 0.2008 - val_accuracy: 0.8955 - val_auc: 0.9472 - val_loss: 0.2744 - learning_rate: 0.0010
# Epoch 34/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9262 - auc: 0.9681 - loss: 0.2020 - val_accuracy: 0.9130 - val_auc: 0.9613 - val_loss: 0.2421 - learning_rate: 0.0010
# Epoch 35/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9266 - auc: 0.9688 - loss: 0.2013 - val_accuracy: 0.9150 - val_auc: 0.9611 - val_loss: 0.2339 - learning_rate: 0.0010
# Epoch 36/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9279 - auc: 0.9706 - loss: 0.1964 - val_accuracy: 0.9102 - val_auc: 0.9603 - val_loss: 0.2531 - learning_rate: 0.0010
# Epoch 37/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9291 - auc: 0.9706 - loss: 0.1922 - val_accuracy: 0.9093 - val_auc: 0.9640 - val_loss: 0.2438 - learning_rate: 0.0010
# Epoch 38/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 44ms/step - accuracy: 0.9377 - auc: 0.9761 - loss: 0.1723 - val_accuracy: 0.9184 - val_auc: 0.9672 - val_loss: 0.2203 - learning_rate: 5.0000e-04
# Epoch 39/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9406 - auc: 0.9790 - loss: 0.1620 - val_accuracy: 0.9141 - val_auc: 0.9651 - val_loss: 0.2281 - learning_rate: 5.0000e-04
# Epoch 40/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9448 - auc: 0.9802 - loss: 0.1558 - val_accuracy: 0.9184 - val_auc: 0.9658 - val_loss: 0.2215 - learning_rate: 5.0000e-04
# Epoch 41/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9455 - auc: 0.9809 - loss: 0.1533 - val_accuracy: 0.9150 - val_auc: 0.9658 - val_loss: 0.2284 - learning_rate: 5.0000e-04
# Epoch 42/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9446 - auc: 0.9796 - loss: 0.1563 - val_accuracy: 0.9189 - val_auc: 0.9638 - val_loss: 0.2382 - learning_rate: 5.0000e-04
# Epoch 43/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9446 - auc: 0.9812 - loss: 0.1539 - val_accuracy: 0.9184 - val_auc: 0.9677 - val_loss: 0.2193 - learning_rate: 5.0000e-04
# Epoch 44/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9471 - auc: 0.9817 - loss: 0.1489 - val_accuracy: 0.9184 - val_auc: 0.9658 - val_loss: 0.2469 - learning_rate: 5.0000e-04
# Epoch 45/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9477 - auc: 0.9826 - loss: 0.1458 - val_accuracy: 0.9186 - val_auc: 0.9664 - val_loss: 0.2214 - learning_rate: 5.0000e-04
# Epoch 46/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9468 - auc: 0.9833 - loss: 0.1448 - val_accuracy: 0.9192 - val_auc: 0.9657 - val_loss: 0.2337 - learning_rate: 5.0000e-04
# Epoch 47/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9477 - auc: 0.9834 - loss: 0.1438 - val_accuracy: 0.9246 - val_auc: 0.9670 - val_loss: 0.2335 - learning_rate: 5.0000e-04
# Epoch 48/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9474 - auc: 0.9838 - loss: 0.1415 - val_accuracy: 0.9198 - val_auc: 0.9689 - val_loss: 0.2277 - learning_rate: 5.0000e-04
# Epoch 49/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9548 - auc: 0.9864 - loss: 0.1262 - val_accuracy: 0.9232 - val_auc: 0.9681 - val_loss: 0.2345 - learning_rate: 2.5000e-04
# Epoch 50/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9560 - auc: 0.9869 - loss: 0.1247 - val_accuracy: 0.9209 - val_auc: 0.9673 - val_loss: 0.2340 - learning_rate: 2.5000e-04

# %% [markdown]
# Evaulate the model

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = (model.predict(X_test) > 0.5).astype(int).flatten()

print(classification_report(y_test, y_pred, target_names=['Non-Fall', 'Fall']))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['Non-Fall','Fall'], yticklabels=['Non-Fall','Fall'])
plt.title("Confusion Matrix"); plt.show()
# Out:
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step
#               precision    recall  f1-score   support
#
#     Non-Fall       0.93      0.96      0.94      3732
#         Fall       0.92      0.88      0.90      2168
#
#     accuracy                           0.93      5900
#    macro avg       0.93      0.92      0.92      5900
# weighted avg       0.93      0.93      0.93      5900
