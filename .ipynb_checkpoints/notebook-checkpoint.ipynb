# %% [markdown]
# This project usus Python 3.10.20, Tensorflow 2.12.0, and mediapipe 0.10.33

# %%
import os
import shutil
import kagglehub
from pathlib import Path

target_dir = "../fall-video-dataset"

# Check if dataset already exists
if Path(target_dir).exists() and any(Path(target_dir).iterdir()):
    print("Dataset already exists, skipping download.")
else:
    print("Downloading dataset...")
    path = kagglehub.dataset_download("payutch/fall-video-dataset")
    print("Path to dataset files:", path)

    os.makedirs(target_dir, exist_ok=True)

    for item in os.listdir(path):
        s = os.path.join(path, item)
        d = os.path.join(target_dir, item)

        if os.path.isdir(s):
            shutil.copytree(s, d, dirs_exist_ok=True)
        else:
            shutil.copy2(s, d)

    print("Dataset copied to:", target_dir)
# Out:
# Dataset already exists, skipping download.

# %%
import tensorflow as tf

# %% [markdown]
# Below is the short description as provided in the kaggle page we downloaded the dataset from Kaggle
#
# ```About this directory```
#
# ```-Raw_Video directory contains raw video footage of human fall.```
#
# ```-Keypoints_CSV directory```
#
# ```-For each input video (e.g., video1.mp4 in Fall/Raw_Video/), the script generates a corresponding CSV file (e.g., video1_keypoints.csv in Fall/Keypoints_CSV/).```
#
# ```-Each CSV file contains frame-by-frame data of the 17 extracted keypoints, their 2D coordinates, and confidence scores.```
#
# ```-The CSV file will have columns: "Frame", "Keypoint", "X", "Y", "Confidence".```
#
#
#
#
#
# Referencing the dataset description on the kaggle page, we load the CSV into frame vectors

# %% [markdown]
# Load and Preprocess the CSV's

# %%
import pandas as pd
import numpy as np 
from pathlib import Path

def load_video_keypoints(csv_path):
    df = pd.read_csv(csv_path)
    frames = sorted(df['Frame'].unique())
    keypoints_per_frame = []

    for frame in frames:
        frame_data = df[df['Frame'] == frame].sort_values('Keypoint')
        # Shape: (17, 3) — x, y, confidence
        kp = frame_data[['X', 'Y', 'Confidence']].values
        keypoints_per_frame.append(kp)

    return np.array(keypoints_per_frame)  # (T, 17, 3)

# %% [markdown]
# Build a Sliding Window Dataset, using 30 frame windows

# %%
def create_sequences(keypoints, label, window_size=30, stride=15):
    sequences, labels = [], []
    T = len(keypoints)
    for start in range(0, T - window_size + 1, stride):
        seq = keypoints[start:start + window_size]  # (30, 17, 3)
        sequences.append(seq)
        labels.append(label)
    return sequences, labels

# Build full dataset
def build_dataset(fall_csv_dir, non_fall_csv_dir, window_size=30):
    X, y = [], []
    for path in Path(fall_csv_dir).glob("*.csv"):
        kp = load_video_keypoints(path)
        seqs, labs = create_sequences(kp, label=1, window_size=window_size)
        X.extend(seqs); y.extend(labs)

    for path in Path(non_fall_csv_dir).glob("*.csv"):
        kp = load_video_keypoints(path)
        seqs, labs = create_sequences(kp, label=0, window_size=window_size)
        X.extend(seqs); y.extend(labs)

    return np.array(X), np.array(y)  # (N, 30, 17, 3)

# %% [markdown]
# Normalize the Data and save as a .npz file

# %%
def normalize_keypoints(X):
    # X shape: (N, T, 17, 3)
    xy = X[..., :2]  # (N, T, 17, 2)
    conf = X[..., 2:3]

    min_xy = xy.min(axis=2, keepdims=True)  # per frame min
    max_xy = xy.max(axis=2, keepdims=True)
    range_xy = np.where((max_xy - min_xy) == 0, 1, max_xy - min_xy)

    xy_norm = (xy - min_xy) / range_xy  # → [0, 1]
    return np.concatenate([xy_norm, conf], axis=-1)


# Run and saved once as sa compressed npz file to quicken training
# X, y = build_dataset(r"..\fall-video-dataset\Fall\Keypoints_CSV", r"..\fall-video-dataset\No_Fall\Keypoints_CSV")
# X = normalize_keypoints(X)

# np.savez_compressed("dataset_cache.npz", X=X, y=y)
data = np.load("dataset_cache.npz")
X, y = data['X'], data['y']

# %% [markdown]
# Train/Validate/Split, so we dont have to make our own training dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.15, stratify=y_train, random_state=42)

print(f"Train: {X_train.shape}, Val: {X_val.shape}, Test: {X_test.shape}")
# Out:
# Train: (20057, 30, 17, 3), Val: (3540, 30, 17, 3), Test: (5900, 30, 17, 3)

# %% [markdown]
# Build CNN (Convolutional Neural Networks) + LSTM (Long Short-Term Memory networks) model

# %%
import tensorflow as tf
from keras import layers, models

def build_cnn_lstm(window_size=30, n_keypoints=17, n_features=3):
    inputs = tf.keras.Input(shape=(window_size, n_keypoints, n_features))

    # --- CNN block applied to each frame via TimeDistributed ---
    x = layers.TimeDistributed(layers.Conv1D(64, kernel_size=3, activation='relu', padding='same'))(inputs)
    x = layers.TimeDistributed(layers.BatchNormalization())(x)
    x = layers.TimeDistributed(layers.Conv1D(128, kernel_size=3, activation='relu', padding='same'))(x)
    x = layers.TimeDistributed(layers.GlobalAveragePooling1D())(x)  # (batch, T, 128)

    # --- LSTM block for temporal modeling ---
    x = layers.LSTM(128, return_sequences=True, dropout=0.3)(x)
    x = layers.LSTM(64, dropout=0.3)(x)

    # --- Classifier head ---
    x = layers.Dense(64, activation='relu')(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model

model = build_cnn_lstm()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 30, 17, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed                │ (None, 30, 17, 64)     │           640 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 30, 17, 64)     │           256 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 30, 17, 128)    │        24,704 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_3              │ (None, 30, 128)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 30, 128)        │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 210,817 (823.50 KB)
#  Trainable params: 210,689 (823.00 KB)
#  Non-trainable params: 128 (512.00 B)

# %% [markdown]
# Compile and Train the model

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.AUC(name='auc')]
)

callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True, monitor='val_auc', mode='max'),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5),
    tf.keras.callbacks.ModelCheckpoint("best_fall_detection_model.keras", save_best_only=True, monitor='val_auc', mode='max')
]

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 32s 43ms/step - accuracy: 0.7195 - auc: 0.7220 - loss: 0.5719 - val_accuracy: 0.7901 - val_auc: 0.7961 - val_loss: 0.4954 - learning_rate: 0.0010
# Epoch 2/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.7982 - auc: 0.8232 - loss: 0.4716 - val_accuracy: 0.8325 - val_auc: 0.8583 - val_loss: 0.4248 - learning_rate: 0.0010
# Epoch 3/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.8233 - auc: 0.8588 - loss: 0.4243 - val_accuracy: 0.8438 - val_auc: 0.8774 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 4/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.8391 - auc: 0.8761 - loss: 0.3984 - val_accuracy: 0.8492 - val_auc: 0.8897 - val_loss: 0.3787 - learning_rate: 0.0010
# Epoch 5/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.8473 - auc: 0.8879 - loss: 0.3816 - val_accuracy: 0.8534 - val_auc: 0.8988 - val_loss: 0.3675 - learning_rate: 0.0010
# Epoch 6/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s
50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9355 - auc: 0.9733 - loss: 0.1820 - val_accuracy: 0.9232 - val_auc: 0.9658 - val_loss: 0.2166 - learning_rate: 0.0010
# Epoch 41/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9377 - auc: 0.9755 - loss: 0.1756 - val_accuracy: 0.9178 - val_auc: 0.9645 - val_loss: 0.2262 - learning_rate: 0.0010
# Epoch 42/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9362 - auc: 0.9750 - loss: 0.1770 - val_accuracy: 0.9161 - val_auc: 0.9651 - val_loss: 0.2243 - learning_rate: 0.0010
# Epoch 43/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9368 - auc: 0.9759 - loss: 0.1731 - val_accuracy: 0.9181 - val_auc: 0.9652 - val_loss: 0.2351 - learning_rate: 0.0010
# Epoch 44/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9364 - auc: 0.9764 - loss: 0.1722 - val_accuracy: 0.9175 - val_auc: 0.9640 - val_loss: 0.2281 - learning_rate: 0.0010
# Epoch 45/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9379 - auc: 0.9764 - loss: 0.1713 - val_accuracy: 0.9167 - val_auc: 0.9642 - val_loss: 0.2389 - learning_rate: 0.0010
# Epoch 46/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.9456 - auc: 0.9814 - loss: 0.1510 - val_accuracy: 0.9240 - val_auc: 0.9693 - val_loss: 0.2171 - learning_rate: 5.0000e-04
# Epoch 47/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.9514 - auc: 0.9840 - loss: 0.1393 - val_accuracy: 0.9251 - val_auc: 0.9682 - val_loss: 0.2258 - learning_rate: 5.0000e-04
# Epoch 48/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 26s 42ms/step - accuracy: 0.9507 - auc: 0.9830 - loss: 0.1419 - val_accuracy: 0.9226 - val_auc: 0.9680 - val_loss: 0.2210 - learning_rate: 5.0000e-04
# Epoch 49/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 42ms/step - accuracy: 0.9536 - auc: 0.9839 - loss: 0.1381 - val_accuracy: 0.9251 - val_auc: 0.9701 - val_loss: 0.2168 - learning_rate: 5.0000e-04
# Epoch 50/50
# 627/627 ━━━━━━━━━━━━━━━━━━━━ 27s 43ms/step - accuracy: 0.9511 - auc: 0.9849 - loss: 0.1356 - val_accuracy: 0.9254 - val_auc: 0.9718 - val_loss: 0.2184 - learning_rate: 5.0000e-04

# %% [markdown]
# Evaulate the model

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = (model.predict(X_test) > 0.5).astype(int).flatten()

print(classification_report(y_test, y_pred, target_names=['Non-Fall', 'Fall']))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', xticklabels=['Non-Fall','Fall'], yticklabels=['Non-Fall','Fall'])
plt.title("Confusion Matrix"); plt.show()
# Out:
# 185/185 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
#               precision    recall  f1-score   support
#
#     Non-Fall       0.95      0.94      0.95      3732
#         Fall       0.90      0.91      0.91      2168
#
#     accuracy                           0.93      5900
#    macro avg       0.92      0.93      0.93      5900
# weighted avg       0.93      0.93      0.93      5900

# %% [markdown]
# Install required libraries for next step
#
# ```pip install opencv-python mediapipe tensorflow numpy```

# %%
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp
from collections import deque

# --- Config ---
MODEL_PATH    = r"./best_fall_detection_model.keras"
WINDOW_SIZE   = 30       # must match what you trained with
THRESHOLD     = 0.7      # confidence threshold for fall detection
COOLDOWN_SEC  = 3        # seconds before another alert can trigger

# --- Load model ---
model = tf.keras.models.load_model(MODEL_PATH)

# --- Mediapipe pose ---
from mediapipe.python.solutions import pose as mp_pose
from mediapipe.python.solutions import drawing_utils as mp_drawing
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# --- State ---
frame_buffer  = deque(maxlen=WINDOW_SIZE)   # rolling window of keypoints
cooldown      = 0                            # frames remaining in cooldown
fall_detected = False

def extract_keypoints(results, frame_w, frame_h):
    """Extract 17 keypoints (x, y, confidence) from mediapipe results."""
    if not results.pose_landmarks:
        return None

    # Mediapipe gives 33 landmarks — take first 17 to match training data
    keypoints = []
    for i, lm in enumerate(results.pose_landmarks.landmark[:17]):
        keypoints.append([
            lm.x,           # already normalized 0-1
            lm.y,
            lm.visibility   # use as confidence
        ])
    return np.array(keypoints)  # (17, 3)

def normalize_keypoints(seq):
    """Same normalization used during training."""
    seq = np.array(seq)         # (T, 17, 3)
    xy   = seq[..., :2]
    conf = seq[..., 2:3]
    min_xy   = xy.min(axis=1, keepdims=True)
    max_xy   = xy.max(axis=1, keepdims=True)
    range_xy = np.where((max_xy - min_xy) == 0, 1, max_xy - min_xy)
    xy_norm  = (xy - min_xy) / range_xy
    return np.concatenate([xy_norm, conf], axis=-1)  # (T, 17, 3)

def predict_fall(frame_buffer):
    """Run model inference on current buffer."""
    seq      = normalize_keypoints(list(frame_buffer))  # (T, 17, 3)
    seq      = np.expand_dims(seq, axis=0)              # (1, T, 17, 3)
    prob     = model.predict(seq, verbose=0)[0][0]
    return prob

# --- Webcam loop ---
cap = cv2.VideoCapture(0)
fps = cap.get(cv2.CAP_PROP_FPS) or 30

print("Starting webcam... Press Q to quit.")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    h, w = frame.shape[:2]

    # --- Pose estimation ---
    rgb     = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = pose.process(rgb)

    # --- Extract keypoints ---
    keypoints = extract_keypoints(results, w, h)

    if keypoints is not None:
        frame_buffer.append(keypoints)

    # --- Run model when buffer is full ---
    if len(frame_buffer) == WINDOW_SIZE and cooldown == 0:
        prob = predict_fall(frame_buffer)

        if prob >= THRESHOLD:
            fall_detected = True
            cooldown      = int(COOLDOWN_SEC * fps)
            print(f"⚠️  FALL DETECTED (confidence: {prob:.2f})")

    # --- Draw skeleton ---
    if results.pose_landmarks:
        mp_drawing.draw_landmarks(frame, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

    # --- Overlay UI ---
    bar_color = (0, 0, 255) if fall_detected else (0, 255, 0)
    label     = "⚠ FALL DETECTED" if fall_detected else "Monitoring..."
    prob_text = f"Fall prob: {prob:.2f}" if len(frame_buffer) == WINDOW_SIZE else "Buffering..."

    cv2.rectangle(frame, (0, 0), (w, 60), (0, 0, 0), -1)           # black bar
    cv2.putText(frame, label,     (10, 35), cv2.FONT_HERSHEY_SIMPLEX, 1.0, bar_color, 2)
    cv2.putText(frame, prob_text, (10, 55), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 1)

    # Buffer fill indicator
    buf_pct = len(frame_buffer) / WINDOW_SIZE
    cv2.rectangle(frame, (0, h-10), (int(w * buf_pct), h), (0, 165, 255), -1)

    cv2.imshow("Fall Detection", frame)

    # --- Cooldown tick ---
    if cooldown > 0:
        cooldown -= 1
    if cooldown == 0:
        fall_detected = False

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
pose.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 17
#      14 model = tf.keras.models.load_model(MODEL_PATH)
#      16 # --- Mediapipe pose ---
# ---> 17 from mediapipe.python.solutions import pose as mp_pose
#      18 from mediapipe.python.solutions import drawing_utils as mp_drawing
#      19 pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)
#
# ModuleNotFoundError: No module named 'mediapipe.python'
